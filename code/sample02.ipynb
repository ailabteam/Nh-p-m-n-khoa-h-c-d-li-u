# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
import sys
print(sys.version)
# Out:
# 3.6.9 (default, Nov  7 2019, 10:44:02)
# [GCC 8.3.0]

# %%
# chú thích
print('ok')
'''
chú thích nhiều dòng
dòng 1
dòng 2
'''
# Out:
# ok
# '\nchú thích nhiều dòng\ndòng 1\ndòng 2\n'

# %%
print('hello')
# Out:
# hello

# %%
print('correct')
frint('sai')
print('correct')
# Out:
# correct
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a636bef7a208> in <module>()
#       1 print('correct')
# ----> 2 frint('sai')
#       3 print('correct')
#
# NameError: name 'frint' is not defined

# %%
print(4/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-4bf1a7e4a751> in <module>()
# ----> 1 print(4/0)
#
# ZeroDivisionError: division by zero

# %%
print(type('hello'))
print(type(1.9))
print(type(-3))
print(type(True))
print(type(False))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>

# %%
print(type(6/2))
print(type(6//2))
# Out:
# <class 'float'>
# <class 'int'>

# %%
import sys
print(sys.float_info)
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
print(type(float('3.12')))
print(int('34'))
print(str(35), type(str(35)))
print(type(int('3')))
# Out:
# <class 'float'>
# 34
# 35 <class 'str'>
# <class 'int'>

# %%
print(int(False))
# Out:
# 0

# %%
print(3 * 3)
# Out:
# 9

# %%
print(5 * 3 + 4)
# Out:
# 19

# %%
print(type(4 * 3))
# Out:
# <class 'int'>

# %%
print(5 ** 2)
# Out:
# 25

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5//2)
# Out:
# 2

# %%
print(5 % 2)
# Out:
# 1

# %%
x = 3 * 3 + 1
print(x, type(x))
# Out:
# 10 <class 'int'>

# %%
y = 2 * x + 1
print(y)
# Out:
# 21

# %%
x = (int)(input('Nhap vao: '))
print(x, type(x))
# Out:
# Nhap vao: 12
# 12 <class 'int'>

# %%
y = (float)(input('nhap vao: '))
print(y, type(y))
# Out:
# nhap vao: 3.45
# 3.45 <class 'float'>

# %%
print(1, 2, 3, sep=',')
# Out:
# 1,2,3

# %%
print(1, 2, sep = '\t')
# Out:
# 1	2

# %%
print('a', 1, 'b', sep = 'yes')
# Out:
# ayes1yesb
