# %%
lst = [1, 2, 3, 'hello', 3.3, True, 100]

# %%
print(lst)
print(len(lst))
print(lst[0])
print(lst[-1])
# Out:
# [1, 2, 3, 'hello', 3.3, True, 100]
# 7
# 1
# 100

# %%
print(type(lst[-2]))
# Out:
# <class 'bool'>

# %%
lst = [1, 3.4, True, ('tuple', 3, 'end'), [1, 2, 3], True, 100]
print(lst)
# Out:
# [1, 3.4, True, ('tuple', 3, 'end'), [1, 2, 3], True, 100]

# %%
print(lst[3])
# Out:
# ('tuple', 3, 'end')

# %%
print(lst[3][0])
# Out:
# tuple

# %%
print(lst[3][0][1])
# Out:
# u

# %%
lst = [1, 3.4, True, ('tuple', 3, 'end'), [1, 2, 3], True, 100]
print(lst[1:3])
print(lst[:4])
print(lst[4:])
# Out:
# [3.4, True]
# [1, 3.4, True, ('tuple', 3, 'end')]
# [[1, 2, 3], True, 100]

# %%
lst = [1, 2, 3]
lst.append([4, 5])
print(lst)
print(len(lst))
# Out:
# [1, 2, 3, [4, 5]]
# 4

# %%
lst = [1, 2, 3, 4]
print(lst)
lst[-1] = 111
print(lst)
del(lst[-1])
print(lst)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 111]
# [1, 2, 3]

# %%
name = 'Do Phuc Hao'
name = name.split(' ')
print(name)
print(type(name))
print(name[0])
print(len(name))
# Out:
# ['Do', 'Phuc', 'Hao']
# <class 'list'>
# Do
# 3

# %%
a = [1, 2, 3]
b = a[:] #clone
#b = a # copy
print(a)
print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
a[0] = 999
print(a)
print(b)
# Out:
# [999, 2, 3]
# [1, 2, 3]

# %%
b[-1] = 777
print(a)
print(b)
# Out:
# [999, 2, 3]
# [1, 2, 777]
