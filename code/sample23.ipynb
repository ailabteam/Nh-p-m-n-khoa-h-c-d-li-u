# %%
# !pip install nba_api

# %%
from nba_api.stats.static import teams

# %%
teams_nba = teams.get_teams()

# %%
print(len(teams_nba))
# Out:
# 30

# %%
print(teams_nba[0:2])
# Out:
# [{'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Atlanta', 'year_founded': 1949}, {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS', 'nickname': 'Celtics', 'city': 'Boston', 'state': 'Massachusetts', 'year_founded': 1946}]

# %%
print(type(teams_nba))
# Out:
# <class 'list'>

# %%
keys = teams_nba[0].keys()
out_dict = {key:[] for key in keys}
print(out_dict)
# Out:
# {'id': [], 'full_name': [], 'abbreviation': [], 'nickname': [], 'city': [], 'state': [], 'year_founded': []}

# %%
print(keys)
# Out:
# dict_keys(['id', 'full_name', 'abbreviation', 'nickname', 'city', 'state', 'year_founded'])
