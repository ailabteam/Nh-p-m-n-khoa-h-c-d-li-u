# %%
import pandas as pd
import numpy as np

# %%
S = pd.Series(np.random.randint(100, size = 5))
print(S)
print(type(S))
# Out:
# 0    82
# 1     3
# 2    13
# 3     1
# 4    53
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(S.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(S.values)
# Out:
# [82  3 13  1 53]

# %%
chiso = ['kien truc', 'cntt', 'dulich', 'xay dung']
giatri = [123, 435, 321, 871]
S = pd.Series(giatri, index = chiso)
print(S)
# Out:
# kien truc    123
# cntt         435
# dulich       321
# xay dung     871
# dtype: int64

# %%
print(S.index)
# Out:
# Index(['kien truc', 'cntt', 'dulich', 'xay dung'], dtype='object')

# %%
print(S.values)
# Out:
# [123 435 321 871]

# %%
dic = {
    'a': [1, 2, 3, 4, 5],
    'b': [1.3, 3.4, 4.5, 5.8, 9],
    'c': ['v1', 'v3', 'v2', 'v5', 'v8']
}
df = pd.DataFrame(dic)
print(df)
print(type(df))
print(df.info())
# Out:
#    a    b   c
# 0  1  1.3  v1
# 1  2  3.4  v3
# 2  3  4.5  v2
# 3  4  5.8  v5
# 4  5  9.0  v8
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       5 non-null      int64
#  1   b       5 non-null      float64
#  2   c       5 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes
# None

# %%
print(df.head(2))
# Out:
#    a    b   c
# 0  1  1.3  v1
# 1  2  3.4  v3

# %%
print(df.tail(3))
# Out:
#    a    b   c
# 2  3  4.5  v2
# 3  4  5.8  v5
# 4  5  9.0  v8

# %%
print(df.columns.values)
# Out:
# ['a' 'b' 'c']

# %%
print(df.index.values)
# Out:
# [0 1 2 3 4]

# %%
print(df.shape)
# Out:
# (5, 3)
