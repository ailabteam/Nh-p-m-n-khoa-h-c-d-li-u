# %%
print('Do Phuc Hao')
# Out:
# Do Phuc Hao

# %%
print("Hello world")
print("32 34 3 43")
print('&^%%&^JJ^^**I*(*(')
# Out:
# Hello world
# 32 34 3 43
# &^%%&^JJ^^**I*(*(

# %%
name = 'Do Phuc Hao'
print('ho ten:', name)
print(type(name))
# Out:
# ho ten: Do Phuc Hao
# <class 'str'>

# %%
name = 'Do Phuc Hao'
print(name, len(name))
print(name[0])
print(name[-2])
# Out:
# Do Phuc Hao 11
# D
# a

# %%
name = 'Do Phuc Hao'
print(name)
print(name[0:2])
print(name[3:])
print(name[-3:])
print(name[::3])
print(name[1:5:2])
# Out:
# Do Phuc Hao
# Do
# Phuc Hao
# Hao
# DPca
# oP

# %%
name = 'Do Phuc Hao'
print(name + ' teaching for his students')
print(3 * name)
# Out:
# Do Phuc Hao teaching for his students
# Do Phuc HaoDo Phuc HaoDo Phuc Hao

# %%
print('Hello \nWorld')
print('Hello \tWorld')
print('Hello \'Hello\'')
# Out:
# Hello
# World
# Hello 	World
# Hello 'Hello'

# %%
name = 'Do Phuc Hao'
print(name)
print(name.upper())
print(name.lower())
name = name.replace('Do', 'Nguyen')
print(name)
# Out:
# Do Phuc Hao
# DO PHUC HAO
# do phuc hao
# Nguyen Phuc Hao

# %%
print(name.find('Hao'))
# Out:
# 12

# %%
print(name.find('jkdsf'))
# Out:
# -1
