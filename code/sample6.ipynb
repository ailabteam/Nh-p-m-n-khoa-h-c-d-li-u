# %%
dic = {'key1': 1, 'key2': 'hello', 'key3': ('tuples', 1, 'end'), (0,1 ): True}
print(dic)
# Out:
# {'key1': 1, 'key2': 'hello', 'key3': ('tuples', 1, 'end'), (0, 1): True}

# %%
print(dic['key3'])
# Out:
# ('tuples', 1, 'end')

# %%
print(type(dic['key3']))
# Out:
# <class 'tuple'>

# %%
dic = {'key1': 1, 'key2': 'hello', 'key1': 333}
print(dic)
# Out:
# {'key1': 333, 'key2': 'hello'}

# %%
print(dic)
# Out:
# {'key1': 333, 'key2': 'hello'}

# %%
print(dic.keys())
# Out:
# dict_keys(['key1', 'key2'])

# %%
print(type(dic.keys()))
# Out:
# <class 'dict_keys'>

# %%
print(dic.values())
# Out:
# dict_values([333, 'hello'])

# %%
dic = {'key1': 1, 'key2': 'hello', 'key3': ('tuples', True, 1.2), (9, 1): False, 'key4': 3.14}
print(dic)
# Out:
# {'key1': 1, 'key2': 'hello', 'key3': ('tuples', True, 1.2), (9, 1): False, 'key4': 3.14}

# %%
print(dic[(9, 1)])
dic['key_n'] = 'new value'
print(dic)
# Out:
# False
# {'key1': 1, 'key2': 'hello', 'key3': ('tuples', True, 1.2), (9, 1): False, 'key4': 3.14, 'key_n': 'new value'}

# %%
del(dic['key_n'])

# %%
print(dic)
# Out:
# {'key1': 1, 'key2': 'hello', 'key3': ('tuples', True, 1.2), (9, 1): False, 'key4': 3.14}

# %%
print(dic.keys())
# Out:
# dict_keys(['key1', 'key2', 'key3', (9, 1), 'key4'])

# %%
print(dic.values())
# Out:
# dict_values([1, 'hello', ('tuples', True, 1.2), False, 3.14])

# %%
dic['key_n'] = 'new value'
print(dic)
# Out:
# {'key1': 1, 'key2': 'hello', 'key3': ('tuples', True, 1.2), (9, 1): False, 'key4': 3.14, 'key_n': 'new value'}

# %%
del(dic['key_n'])
print(dic)
# Out:
# {'key1': 1, 'key2': 'hello', 'key3': ('tuples', True, 1.2), (9, 1): False, 'key4': 3.14}

# %%
print(('key11') in dic)
# Out:
# False
