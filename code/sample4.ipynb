# %%
tuples = ('hello', 1, 3.14, True)
print(tuples)
print(len(tuples))
print(type(tuples))
print(tuples[0])
print(tuples[-1])
# Out:
# ('hello', 1, 3.14, True)
# 4
# <class 'tuple'>
# hello
# True

# %%
tuples2 = tuples + ('tuples2', True, 'End')
print(tuples2)
# Out:
# ('hello', 1, 3.14, True, 'tuples2', True, 'End')

# %%
print(tuples2[-2])
# Out:
# True

# %%
t = ['hello', 1, 3.13, True]
print(t[:3])
print(t[3:])
print(t[1:3])
# Out:
# ['hello', 1, 3.13]
# [True]
# [1, 3.13]

# %%
t = (1, 2, 5, 3, 0, 9)
t = sorted(t)
print(t)
# Out:
# [0, 1, 2, 3, 5, 9]

# %%
t = (1, 2, 3, ('hello', 2, True), (3, 4), 'End')
print(t)
# Out:
# (1, 2, 3, ('hello', 2, True), (3, 4), 'End')

# %%
print(t[3], type(t[3]))
# Out:
# ('hello', 2, True) <class 'tuple'>

# %%
print(t[3][0])
# Out:
# hello

# %%
print(t[3][0][1])
# Out:
# e
