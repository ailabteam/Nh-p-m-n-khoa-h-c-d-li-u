# %%
years = map(str, range(3, 10))
print(years)

# %%
print(type(years))
# Out:
# <class 'map'>

# %%
years = list(map(str, range(3, 10)))
print(years)
years = list(range(2, 4))
print(years)
# Out:
# ['3', '4', '5', '6', '7', '8', '9']
# [2, 3]
